# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C://Users//Matthew//DA//Class Notes//12-11//learningSet.csv')
data.shape
# Out:
# (95412, 481)

# %%
pd.set_option('display.max_rows',None)
data.select_dtypes(np.number).isna().sum()/len(data)
# Out:
# ODATEDW     0.000000
# TCODE       0.000000
# DOB         0.000000
# AGE         0.248030
# NUMCHLD     0.870184
# INCOME      0.223096
# WEALTH1     0.468830
# HIT         0.000000
# MBCRAFT     0.553955
# MBGARDEN    0.553955
# MBBOOKS     0.553955
# MBCOLECT    0.554584
# MAGFAML     0.553955
# MAGFEM      0.553955
# MAGMALE     0.553955
# PUBGARDN    0.553955
# PUBCULIN    0.553955
# PUBHLTH     0.553955
# PUBDOITY    0.553955
# PUBNEWFN    0.553955
# PUBPHOTO    0.553955
# PUBOPP      0.553955
# MALEMILI    0.000000
# MALEVET     0.000000
# VIETVETS    0.000000
# WWIIVETS    0.000000
# LOCALGOV    0.000000
# STATEGOV    0.000000
# FEDGOV      0.000000
# WEALTH2     0.459303
# POP901      0.000000
# POP902      0.000000
# POP903      0.000000
# POP90C1     0.000000
# POP90C2     0.000000
# POP90C3     0.000000
# POP90C4     0.000000
# POP90C5     0.000000
# ETH1        0.000000
# ETH2        0.000000
# ETH3        0.000000
# ETH4        0.000000
# ETH5        0.000000
# ...

# %%
datatrial = data[['GEOCODE2','WEALTH1','ADI','DMA','MSA']]

# %%
datatrial.isna().sum()
# Out:
# GEOCODE2      132
# WEALTH1     44732
# ADI           132
# DMA           132
# MSA           132
# dtype: int64

# %%
for col in datatrial.columns:
    print(data[col].value_counts())
# Out:
# A    34484
# B    28505
# D    16580
# C    15524
#        187
# Name: GEOCODE2, dtype: int64
# 9.0    7585
# 8.0    6793
# 7.0    6198
# 6.0    5825
# 5.0    5280
# 4.0    4810
# 3.0    4237
# 2.0    4085
# 1.0    3454
# 0.0    2413
# Name: WEALTH1, dtype: int64
# 13.0     7296
# 51.0     4622
# 65.0     3765
# 57.0     2836
# 105.0    2617
# 197.0    2075
# 109.0    2054
# 131.0    1978
# 67.0     1847
# 201.0    1772
# 107.0    1746
# 275.0    1717
# 233.0    1676
# 127.0    1651
# 329.0    1647
# 75.0     1588
# 241.0    1573
# 15.0     1472
# 83.0     1305
# 351.0    1193
# 111.0    1127
# 279.0    1075
# 213.0    1073
# 59.0     1000
# 157.0     996
# 129.0     955
# 181.0     924
# 281.0     863
# 0.0       843
# 367.0     813
# 271.0     807
# 577.0     773
# 263.0     745
# 335.0     696
# 63.0      686
# 209.0     669
# 179.0     656
# 455.0     645
# 291.0     634
# 337.0     613
# 269.0     611
# 215.0     602
# 245.0     597
# 315.0     585
# 71.0      582
# ...

# %%
datatrial['GEOCODE2'].isna().sum()

# %%
datatrial['GEOCODE2'].value_counts()
datatrial['GEOCODE2'] = datatrial['GEOCODE2'].fillna('A')

# %%
sns.histplot(datatrial['GEOCODE2'])
# Out:
# <AxesSubplot:xlabel='GEOCODE2', ylabel='Count'>

# %%
datatrial['GEOCODE2'].isna().sum()
# Out:
# 0

# %%
datatrial['WEALTH1'].isna().sum()

# %%
sns.distplot(datatrial[datatrial['WEALTH1'].isna()==False]['WEALTH1']) 
plt.show()

# %%
print(datatrial['WEALTH1'].value_counts())
datatrial['WEALTH1'] = datatrial['WEALTH1'].astype('object')
# Out:
# 9.0    7585
# 8.0    6793
# 7.0    6198
# 6.0    5825
# 5.0    5280
# 4.0    4810
# 3.0    4237
# 2.0    4085
# 1.0    3454
# 0.0    2413
# Name: WEALTH1, dtype: int64

# %%
datatrial['WEALTH1'] = datatrial['WEALTH1'].fillna('9.0')

# %%
datatrial['WEALTH1'].isna().sum()

# %%
print(datatrial['WEALTH1'].value_counts())
# Out:
# 9.0    44732
# 9.0     7585
# 8.0     6793
# 7.0     6198
# 6.0     5825
# 5.0     5280
# 4.0     4810
# 3.0     4237
# 2.0     4085
# 1.0     3454
# 0.0     2413
# Name: WEALTH1, dtype: int64

# %%
datatrial['MSA'].isna().sum()

# %%
sns.distplot(datatrial[datatrial['MSA'].isna()==False]['MSA']) 
plt.show()

# %%
datatrial['MSA'] = datatrial['MSA'].fillna(np.mean(datatrial['MSA']))

# %%
sns.distplot(datatrial[datatrial['MSA'].isna()==False]['MSA']) 
plt.show()

# %%
print(datatrial['MSA'].value_counts())
# Out:
# 0.000000       21333
# 4480.000000     4606
# 1600.000000     4059
# 2160.000000     2586
# 520.000000      1685
# 6780.000000     1525
# 5945.000000     1500
# 7320.000000     1472
# 7600.000000     1457
# 3360.000000     1414
# 6200.000000     1409
# 8280.000000     1378
# 7040.000000     1360
# 5775.000000     1255
# 1920.000000     1217
# 5120.000000     1195
# 6440.000000     1076
# 7360.000000     1046
# 2080.000000      993
# 7400.000000      929
# 6920.000000      894
# 5000.000000      824
# 3760.000000      817
# 5960.000000      791
# 3480.000000      790
# 2680.000000      771
# 5080.000000      745
# 4120.000000      722
# 1520.000000      697
# 3120.000000      691
# 8960.000000      644
# 7240.000000      619
# 6640.000000      592
# 2800.000000      584
# 3000.000000      560
# 3600.000000      543
# 5360.000000      523
# 5880.000000      507
# 640.000000       487
# 5560.000000      478
# 8520.000000      474
# 3160.000000      465
# 4920.000000      456
# ...

# %%
datatrial['MSA'].isna().sum()
# Out:
# 0

# %%
datatrial['ADI'].isna().sum()
# Out:
# 132

# %%
sns.distplot(datatrial[datatrial['ADI'].isna()==False]['ADI']) 
plt.show()

# %%
datatrial['ADI'] = datatrial['ADI'].fillna(np.mean(datatrial['ADI']))

# %%
datatrial['ADI'].isna().sum()
# Out:
# 0

# %%
datatrial['DMA'].isna().sum()
# Out:
# 132

# %%
sns.distplot(datatrial[datatrial['DMA'].isna()==False]['DMA']) 
plt.show()

# %%
datatrial['DMA'] = datatrial['DMA'].fillna(np.mean(datatrial['DMA']))

# %%
datatrial['DMA'].isna().sum()
# Out:
# 0
